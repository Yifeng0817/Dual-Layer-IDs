# %%
"""
Show hyperparameter and festures for Layer 2 model

Author: Tan Yi Feng
Student ID: 23WMR14766
"""
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline2.pkl"
features_path = MODELS_DIR / "selected_features2.pkl"


best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)

print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(bootstrap=False,
#                                         class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline3.pkl"
features_path = MODELS_DIR / "selected_features3.pkl"


best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)

print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(bootstrap=False,
#                                         class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline4.pkl"
features_path = MODELS_DIR / "selected_features4.pkl"


best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)

print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(bootstrap=False,
#                                         class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline5.pkl"
features_path = MODELS_DIR / "selected_features5.pkl"


best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)


print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
#                                                       np.int64(8): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline6.pkl"
features_path = MODELS_DIR / "selected_features6.pkl"


best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)

print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
#                                                       np.int64(8): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline7.pkl"
features_path = MODELS_DIR / "selected_features7.pkl"

best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)


print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
#                                                       np.int64(8): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline8.pkl"
features_path = MODELS_DIR / "selected_features8.pkl"

best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)


print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
#                                                       np.int64(8): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline9.pkl"
features_path = MODELS_DIR / "selected_features9.pkl"


best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)

print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
#                                                       np.int64(8): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline10.pkl"
features_path = MODELS_DIR / "selected_features10.pkl"

best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)


print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
#                                                       np.int64(8): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline11.pkl"
features_path = MODELS_DIR / "selected_features11.pkl"


best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)


print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(bootstrap=False,
#                                         class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()

DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline12.pkl"
features_path = MODELS_DIR / "selected_features12.pkl"

best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)


print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
#                                                       np.int64(8): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline13.pkl"
features_path = MODELS_DIR / "selected_features13.pkl"


best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)


print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
#                                                       np.int64(8): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline14.pkl"
features_path = MODELS_DIR / "selected_features14.pkl"


best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)


print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
#                                                       np.int64(8): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline15.pkl"
features_path = MODELS_DIR / "selected_features15.pkl"


best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)


print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
#                                                       np.int64(8): np.float64(0.82328125),
# ...

# %%
from pathlib import Path
import joblib
import pickle
import pandas as pd


SCRIPT_DIR = Path.cwd()


DATASET_PATH = SCRIPT_DIR / 'data' / 'processed' / 'full_inference_cleaned_casing_preserved.csv'
CONFIG_PATH = SCRIPT_DIR / 'config' / 'config.yaml'
MODELS_DIR = SCRIPT_DIR / 'data' / 'models'
SRC_PATH = SCRIPT_DIR / 'src'

model_path = MODELS_DIR / "best_rf_pipeline16.pkl"
features_path = MODELS_DIR / "selected_features16.pkl"


best_model = joblib.load(model_path)
print("✅ Model loaded successfully!")

print("\nPipeline structure:")
print(best_model)


with open(features_path, "rb") as f:
    selected_features = pickle.load(f)

print(f"\nNumber of selected features: {len(selected_features)}")


rf_model = best_model.named_steps['rf']

print("\n==============================")
print("FULL TRAINED MODEL SUMMARY")
print("==============================")


print("\n--- Hyperparameters ---")
print("n_estimators      :", rf_model.n_estimators)
print("max_depth         :", rf_model.max_depth)
print("min_samples_split :", rf_model.min_samples_split)
print("min_samples_leaf  :", rf_model.min_samples_leaf)
print("bootstrap         :", rf_model.bootstrap)
print("criterion         :", rf_model.criterion)
print("class_weight      :", rf_model.class_weight)


print("\n--- Model Structure ---")
print("Number of Trees Built :", len(rf_model.estimators_))
print("Number of Classes     :", rf_model.n_classes_)
print("Classes               :", rf_model.classes_)
print("Number of Features Used:", rf_model.n_features_in_)


print("\n--- Feature Importance ---")

importance_df = pd.DataFrame({
    "Feature": selected_features,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(importance_df)


print("\nTop 10 Important Features:")
print(importance_df.head(10))
# Out:
# ✅ Model loaded successfully!
#
# Pipeline structure:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf',
#                  RandomForestClassifier(class_weight={np.int64(0): np.float64(2.46984375),
#                                                       np.int64(1): np.float64(2.46984375),
#                                                       np.int64(2): np.float64(2.46984375),
#                                                       np.int64(3): np.float64(4.9396875),
#                                                       np.int64(4): np.float64(1.6465625),
#                                                       np.int64(5): np.float64(7.07248322147651),
#                                                       np.int64(6): np.float64(1.0977083333333333),
#                                                       np.int64(7): np.float64(0.82328125),
#                                                       np.int64(8): np.float64(0.82328125),
# ...
